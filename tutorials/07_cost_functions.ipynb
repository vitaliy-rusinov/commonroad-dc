# %% [markdown]
# ## Tutorial 07: Evaluate solution using cost functions
#
# With our implementation of the cost functions from the CommonRoad benchmark, solutions of scenarios can be assessed
# locally before submitting them. More details about the cost functions can be found [here](https://gitlab.lrz.de/tum-cps/commonroad-cost-functions/-/blob/master/costFunctions_commonRoad.pdf).

# %%
import os
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.common.solution import CommonRoadSolutionReader
from commonroad_dc.costs.evaluation import CostFunctionEvaluator

path = os.path.abspath("")

# %% [markdown]
# The solution object can either be read from a Commonroad solution xml file ([this tutorial](https://commonroad.in.tum.de/tutorials/optimization-solution) shows how to create one), or can be created on the fly from a `Trajectory`.
# In this example we use an xml file:

# %%
solution = CommonRoadSolutionReader.open(os.path.join(path, "example_solution_tutorial_cost_functions.xml"))
scenario, planning_problem_set = CommonRoadFileReader(os.path.join(path, "DEU_Guetersloh-36_1_T-1.xml")).open()

ce = CostFunctionEvaluator.init_from_solution(solution)
cost_result = ce.evaluate_solution(scenario, planning_problem_set, solution)

print(cost_result)
# Out:
# successorRight 85161 is of deprecated format, thus mapped to outgoingRight
# successorStraight 85162 is of deprecated format, thus mapped to outgoingStraight
# successorStraight 85229 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85230 is of deprecated format, thus mapped to outgoingLeft
# successorRight 85168 is of deprecated format, thus mapped to outgoingRight
# successorLeft 85167 is of deprecated format, thus mapped to outgoingLeft
# successorStraight 85153 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85154 is of deprecated format, thus mapped to outgoingLeft
# successorStraight 85184 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85185 is of deprecated format, thus mapped to outgoingLeft
# successorRight 85067 is of deprecated format, thus mapped to outgoingRight
# successorLeft 85068 is of deprecated format, thus mapped to outgoingLeft
# successorRight 85224 is of deprecated format, thus mapped to outgoingRight
# successorStraight 85223 is of deprecated format, thus mapped to outgoingStraight
# successorRight 85216 is of deprecated format, thus mapped to outgoingRight
# successorLeft 85215 is of deprecated format, thus mapped to outgoingLeft
# successorStraight 85226 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85227 is of deprecated format, thus mapped to outgoingLeft
# successorStraight 85155 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85156 is of deprecated format, thus mapped to outgoingLeft
# successorStraight 85165 is of deprecated format, thus mapped to outgoingStraight
# successorLeft 85166 is of deprecated format, thus mapped to outgoingLeft
# successorRight 85214 is of deprecated format, thus mapped to outgoingRight
# successorLeft 85213 is of deprecated format, thus mapped to outgoingLeft
# Total costs for benchmark KS2:SM1:DEU_Guetersloh-36_1_T-1:2020a:
# 1429.0919822411302
# Partial costs for solution of planning problem 1:
# A:	1386.666666666668
# SA:	2.6346624296296297
# SR:	11.153123703703699
# L:	27.386666666666667
# V:	0.0
# O:	1.2508627744622218
